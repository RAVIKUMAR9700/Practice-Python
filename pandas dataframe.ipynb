# %%
import pandas as pd
import numpy as np

# %%
#dataframe
df_data=pd.DataFrame([[10,20,30],[40,50,60],[35,45,55]])
print("data frame is\n",df_data)
# Out:
# data frame is
#      0   1   2
# 0  10  20  30
# 1  40  50  60
# 2  35  45  55

# %%
#dataframe index 
df_data=pd.DataFrame([[10,20,30],[40,50,60],[35,45,55]],index=[2018,2019,2020])
print(df_data)
# Out:
#        0   1   2
# 2018  10  20  30
# 2019  40  50  60
# 2020  35  45  55

# %%
#dataframe index and columns
df_data=pd.DataFrame([[10,20,30],[40,50,60],[35,45,55]],index=[2018,2019,2020],
                     columns=['hp','dell','sony'])
print("data frame is \n",df_data)
# Out:
# data frame is
#        hp  dell  sony
# 2018  10    20    30
# 2019  40    50    60
# 2020  35    45    55

# %%
#get data from dataframe
#dataframename[columnname][rowlabel]
df_data['hp'][2019]
# Out:
# 40

# %%
#access value of column
print(df_data.hp)
# Out:
# 2018    10
# 2019    40
# 2020    35
# Name: hp, dtype: int64

# %%
#access value of column
print(df_data['hp'])
# Out:
# 2018    10
# 2019    40
# 2020    35
# Name: hp, dtype: int64

# %%
#access row data dataframename[columnn][row]
print("sales of hp in 2019 \n",df_data['hp'][2019])
# Out:
# sales of hp in 2019
#  40

# %%
#data.loc/iloc[rows:rowe:rowstep,columnstrat:columnend:columnstep]
df_data.loc[2018:2020,"hp":'sony']
# Out:
#       hp  dell  sony
# 2018  10    20    30
# 2019  40    50    60
# 2020  35    45    55

# %%
d2={'laptop':[10,20,30],'mobile':[40,50,60],'watch':[200,300,400]}
dt_item=pd.DataFrame(d2,index=[2010,2011,2012])
print(dt_item)
# Out:
#       laptop  mobile  watch
# 2010      10      40    200
# 2011      20      50    300
# 2012      30      60    400

# %%
dt_item.tail()
# Out:
#       laptop  mobile  watch
# 2010      10      40    200
# 2011      20      50    300
# 2012      30      60    400

# %%
dt_item.head()
# Out:
#       laptop  mobile  watch
# 2010      10      40    200
# 2011      20      50    300
# 2012      30      60    400

# %%
dt_item.describe()
# Out:
#        laptop  mobile  watch
# count     3.0     3.0    3.0
# mean     20.0    50.0  300.0
# std      10.0    10.0  100.0
# min      10.0    40.0  200.0
# 25%      15.0    45.0  250.0
# 50%      20.0    50.0  300.0
# 75%      25.0    55.0  350.0
# max      30.0    60.0  400.0

# %%
df_car=pd.read_csv(r'C:\Users\HP\Downloads/car data.csv')
df_car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
#fule types
pd.unique(df_car['Fuel_Type'])
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
pd.unique(df_car['Transmission'])
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
pd.unique(df_car[''])

# %%
df_car.nunique()
# Out:
# Car_Name          98
# Year              16
# Selling_Price    156
# Present_Price    147
# Kms_Driven       206
# Fuel_Type          3
# Seller_Type        2
# Transmission       2
# Owner              3
# dtype: int64

# %%
df_car.drop('Car_Name',axis=1,inplace=True)

# %%
df_car
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0    2014           3.35           5.59       27000    Petrol      Dealer
# 1    2013           4.75           9.54       43000    Diesel      Dealer
# 2    2017           7.25           9.85        6900    Petrol      Dealer
# 3    2011           2.85           4.15        5200    Petrol      Dealer
# 4    2014           4.60           6.87       42450    Diesel      Dealer
# ..    ...            ...            ...         ...       ...         ...
# 296  2016           9.50          11.60       33988    Diesel      Dealer
# 297  2015           4.00           5.90       60000    Petrol      Dealer
# 298  2009           3.35          11.00       87934    Petrol      Dealer
# 299  2017          11.50          12.50        9000    Diesel      Dealer
# 300  2016           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner
# 0         Manual      0
# 1         Manual      0
# ...

# %%
pd.get_dummies(df_car)
# Out:
#      Year  Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_CNG  \
# 0    2014           3.35           5.59       27000      0              0
# 1    2013           4.75           9.54       43000      0              0
# 2    2017           7.25           9.85        6900      0              0
# 3    2011           2.85           4.15        5200      0              0
# 4    2014           4.60           6.87       42450      0              0
# ..    ...            ...            ...         ...    ...            ...
# 296  2016           9.50          11.60       33988      0              0
# 297  2015           4.00           5.90       60000      0              0
# 298  2009           3.35          11.00       87934      0              0
# 299  2017          11.50          12.50        9000      0              0
# 300  2016           5.30           5.90        5464      0              0
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Dealer  \
# ...

# %%
df_car=pd.get_dummies(df_car,drop_first=True)
df_car.head(10)
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven  Owner  Fuel_Type_Diesel  \
# 0  2014           3.35           5.59       27000      0                 0
# 1  2013           4.75           9.54       43000      0                 1
# 2  2017           7.25           9.85        6900      0                 0
# 3  2011           2.85           4.15        5200      0                 0
# 4  2014           4.60           6.87       42450      0                 1
# 5  2018           9.25           9.83        2071      0                 1
# 6  2015           6.75           8.12       18796      0                 0
# 7  2015           6.50           8.61       33429      0                 1
# 8  2016           8.75           8.89       20273      0                 1
# 9  2015           7.45           8.92       42367      0                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# ...
